# %% [markdown]
# # How to set up VS Code for your exam
#
# In this notebook you will prepare your computer to take the exam.

# %% [markdown]
# ## Step 1 - Open the file
# Open this file using VSCode. Sometimes VSCode has trouble opening the file as a Jupyter Notebook and the file looks funny when it opens. If this happens, close the file and then reopen it using VSCode again.

# %% [markdown]
# ## Step 2 - Make sure you have the Jupyter Extension Installed
#
# Using the **left-hand side toolbar**, click on the extensions button (circled in red below)
#
# <img src="Explain_VSCode_Extension_Location.jpg"
#      width=50 />
#
# A toolbar with the extensions that are already installed will show up. If you do not see the **'Jupyter'** extension listed, search for it in the search bar and then click the blue install button.

# %% [markdown]
# ## Step 3 - Run some code

# %%
print('Hello World!')

# %% [markdown]
# ## Step 4 - Trust the file
#
# Sometimes you will be asked: Do you trust this file? If you are asked this, click Yes.

# %% [markdown]
# ## Step 5 - Choose the Anaconda Python Kernel
#
# In the **upper right hand corner**, click "Select Kernel". It is possible it has already selected a kernel for you so it might say something else in that same spot. Either way, click that spot (circled in red below). Then you will see a drop down menu at the top of your screen. Click "Python Environments..." and then click "Anaconda3".
#
# <img src="Setup_VSCode_Kernel.jpg"
#      width=500 />

# %% [markdown]
# ## Step 6 - Test to make sure your code runs with the necessary modules
#
# Run the cell below and let the instructor know if you have any issues when you try to run it.

# %%
import pandas as pd
data = {'letters': ["A", "B", "C"],
        'nums': [1, 2, 3]}

df = pd.DataFrame(data)
print(df)
