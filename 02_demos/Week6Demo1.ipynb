# %% [markdown]
# # Striding with Range

# %% [markdown]
# # Striding with Range in Loops
#
# What if we have a list of numbers and we only want to print out every other number on a new line using a for loop?

# %% [markdown]
# What about even numbers counting backwards?

# %% [markdown]
# **Student Task**
#
# Make a list of 10 sports, where each element is a string. Print them out backwards, skipping every other sport, using a For Loop.

# %% [markdown]
# # When you need to use a loop variable as an index
#
# If you need to loop over multiple variables, it is best to use your loop variable as an index.
#
# For example, say we have a list of people, and a list of those people's favorite colors. And say we want to print the person's name out with their favorite color.

# %%
person = ['Nathan','Malik','Jayden','Jose']
fav_color = ['pink', 'orange', 'purple', 'green']

# %% [markdown]
# **Student Task**
#
# Multiply the list elements with the same index together. Store the resulting product in a new list. Print out the list.

# %%
list1 = [0,1,2,3,4]
list2 = [5,4,3,2,1]
list3 = [2,2,2,2,2]

# %% [markdown]
# # Nested Loops
#
# SEE SLIDES

# %% [markdown]
# Imagine you want to print out tickets for each seat in an auditorium. The rows are labeled with letters, and the seat numbers are labeled with numbers.

# %%
row = ['A', 'B', 'C', 'D']
seatnum = [1,2,3,4,5,6] #each row has this many seats

# %% [markdown]
# Imagine you have a list within a list.

# %%
nested_list = [[1,2,3],
               [4,5,6],
               [7,8,9]]

# %% [markdown]
# Print out every number in nested_list

# %%
nested_list = [[1,2,3],
               [4,5,6],
               [7,8,9]]

# %% [markdown]
# **Student Task**
#
# Print all possible combinations of 2 dice rolls. Each die has 6 sides.

# %% [markdown]
# **Student Task**
#
# Make up a nested loop problem for your neighbor to solve.  Then solve your neighbor's problem!
