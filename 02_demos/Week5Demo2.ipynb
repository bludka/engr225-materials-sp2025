# %% [markdown]
# # While vs. For Loops
#
# Even though While Loops can complete the same task as For Loops, For Loops are preferred.
#
# Example of While Loops and For Loops completing the same task:

# %% [markdown]
# Do you remember why For Loops are preferred over While Loops?
#
# <img src="https://lh3.googleusercontent.com/pw/ABLVV840ZCFzL09CK3MLny9MrgQeqJxWlY6xblZbxMNnGBYOGbcOzJZWPD788JQX45DRUoMxgJQeyoQV06dryr45xfi6EbXUSfL9OoeAAfVdx0bwYKk1jjxDN2ye3nVqxA5Uq9QknWcPRPMUPXzH2hdSm2io=w316-h421-s-no-gm?authuser=0"
#      width=200 />

# %% [markdown]
# ## Using Range in a Loop

# %% [markdown]
# Same example!
#
# Note: range(1,6) includes 1 to 5 and does NOT include 6.

# %% [markdown]
# **Quick Student Task**
#
# Following the example above
# print out the numbers 100 to 110 using a for loop and a range() function

# %%
# your code here

# %% [markdown]
# If you only give range one input, it starts at 0

# %% [markdown]
# ## Using an index for the loop variable

# %% [markdown]
# ## Using a value for the loop variable

# %% [markdown]
# ## Combining For Loops and If Statements

# %% [markdown]
# What if we wanted to print out all the numbers that are divisible by 3?

# %% [markdown]
# ## Counting
#
# What if we wanted to COUNT all the numbers that are divisible by 3?

# %% [markdown]
# What if we wanted to COUNT all the numbers that are greater than 3?

# %% [markdown]
# ## Summing
#
# What if we wanted to SUM all the numbers in the list?

# %% [markdown]
# ## Calculating an average using a sum found in a loop
#
# Calculate the average of the numbers in the list

# %% [markdown]
# ## Storing calulations
#
# What if I wanted to make a new list, where each element had 1 added to it?

# %% [markdown]
# ## More Practice
#
# **Student Task**
#
# Make a list of 5 animals. Print out each animal on a new line using a For Loop. DO THIS TASK TWICE: The first time use the loop variable as a value. The second time, use the loop variable as an index.

# %%
# your code here

# %% [markdown]
# **Student Task**
#
# Use a loop to count the number of 'hi' elements in the list.
#
# DO THIS TASK TWICE: The first time use the loop variable as a value. The second time, use the loop variable as an index.

# %%
mix = [1, 'hi', 5, 'me', 10, 'you', -9, 'happy', 'hi', 'hi']
# your code here

# %% [markdown]
# **Student Task**
#
# Sum all the elements that are integers in this list using a loop.
#
# DO THIS TASK TWICE: The first time use the loop variable as a value. The second time, use the loop variable as an index.

# %%
data = [100, 200, 250, 'NA', 780, 'NA', 900]
# your code here

# %% [markdown]
# **Student Task**
#
# Add an 's' to all the words in the list below using a For Loop and store them in a new list.
#
# DO THIS TASK TWICE: The first time use the loop variable as a value. The second time, use the loop variable as an index.

# %%
word = ['student', 'apple', 'dog', 'mind', 'gem']
# your code here
